# %%
from google.colab import files
files.upload()  # Importing the Dataset
# Out:
#      <input type="file" id="files-883d9246-efa7-4531-8f50-83fa766c7417" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-883d9246-efa7-4531-8f50-83fa766c7417">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# importing necessary libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# This is the data which contains store details
sales_details = pd.read_csv("/content/Walmart_sales.csv")
sales_details
# Out:
#       Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1  05-02-2010    1643690.90             0        42.31       2.572
# 1         1  12-02-2010    1641957.44             1        38.51       2.548
# 2         1  19-02-2010    1611968.17             0        39.93       2.514
# 3         1  26-02-2010    1409727.59             0        46.63       2.561
# 4         1  05-03-2010    1554806.68             0        46.50       2.625
# ...     ...         ...           ...           ...          ...         ...
# 6430     45  28-09-2012     713173.95             0        64.88       3.997
# 6431     45  05-10-2012     733455.07             0        64.89       3.985
# 6432     45  12-10-2012     734464.36             0        54.47       4.000
# 6433     45  19-10-2012     718125.53             0        56.47       3.969
# 6434     45  26-10-2012     760281.43             0        58.85       3.882
#
#              CPI  Unemployment
# ...

# %%
sales_details.tail(10)
# Out:
#       Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 6425     45  24-08-2012     718232.26             0        72.62       3.834
# 6426     45  31-08-2012     734297.87             0        75.09       3.867
# 6427     45  07-09-2012     766512.66             1        75.70       3.911
# 6428     45  14-09-2012     702238.27             0        67.87       3.948
# 6429     45  21-09-2012     723086.20             0        65.32       4.038
# 6430     45  28-09-2012     713173.95             0        64.88       3.997
# 6431     45  05-10-2012     733455.07             0        64.89       3.985
# 6432     45  12-10-2012     734464.36             0        54.47       4.000
# 6433     45  19-10-2012     718125.53             0        56.47       3.969
# 6434     45  26-10-2012     760281.43             0        58.85       3.882
#
#              CPI  Unemployment
# 6425  191.344887         8.684
# 6426  191.461281         8.684
# ...

# %%
sales_details.shape
# Out:
# (6435, 8)

# %%
# missing values in the dataset
print("Total size of dataset: ", len(sales_details))
print(sales_details.isnull().sum())
# Out:
# Total size of dataset:  6435
# Store           0
# Date            0
# Weekly_Sales    0
# Holiday_Flag    0
# Temperature     0
# Fuel_Price      0
# CPI             0
# Unemployment    0
# dtype: int64

# %%
columns = list(sales_details.columns)
for col in columns:
    print(col,"-------->",sales_details[col].unique())

#columns.remove(Column_one)
#columns.remove('Column_two')

# %%
# extracting year and month from Date
sales_details['Year']  = sales_details['Date'].apply(lambda x: int(str(x)[6:]))
sales_details['Month'] = sales_details['Date'].apply(lambda x: int(str(x)[3:5]))

# %%
sales_details.tail(10)
# Out:
#       Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 6425     45  24-08-2012     718232.26             0        72.62       3.834
# 6426     45  31-08-2012     734297.87             0        75.09       3.867
# 6427     45  07-09-2012     766512.66             1        75.70       3.911
# 6428     45  14-09-2012     702238.27             0        67.87       3.948
# 6429     45  21-09-2012     723086.20             0        65.32       4.038
# 6430     45  28-09-2012     713173.95             0        64.88       3.997
# 6431     45  05-10-2012     733455.07             0        64.89       3.985
# 6432     45  12-10-2012     734464.36             0        54.47       4.000
# 6433     45  19-10-2012     718125.53             0        56.47       3.969
# 6434     45  26-10-2012     760281.43             0        58.85       3.882
#
#              CPI  Unemployment  Year  Month
# 6425  191.344887         8.684  2012      8
# ...

# %%
# Weekly Sales with respect to year
sns.barplot(x='Year', y='Weekly_Sales', data=sales_details).set(title='Year vs Sales')
plt.show()

# %%
#Weekly sales vs Holiday
sns.barplot(x='Holiday_Flag', y='Weekly_Sales', data=sales_details).set(title='Holiday presence vs Sales')
plt.show()

# %%
#How stores compare on weekly sales - Store 20 is the best
plt.figure(figsize=(10, 8))
sns.barplot(x='Store', y='Weekly_Sales', data=sales_details).set(title='Stores vs Sales')
plt.show()

# %%
#What makes store 20 have massive sales?
# Filter the data for the year 2010
sales_details_store_20 = sales_details[sales_details['Store'] == 20]
sns.barplot(x='Unemployment', y='Weekly_Sales', data=sales_details_store_20).set(title='comparisons (name as liked)')
plt.figure(figsize=(10, 8))
plt.show()

# %%
# checking distribution of sales
sns.displot(sales_details, x="Weekly_Sales",bins=50).set(title='Dsitribution of Sales')

# %%
plt.figure(figsize=(20,10))
sns.heatmap(sales_details.corr(),annot=True)
# Out:
# <ipython-input-54-84fde072cd81>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(sales_details.corr(),annot=True)
# <Axes: >

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_absolute_percentage_error
import math

# %%
x_train, x_test, y_train, y_test_open = train_test_split(sales_details.drop(
    ['Weekly_Sales', 'Date',], axis=1), sales_details['Weekly_Sales'], test_size=0.20)

# %%
epsilon = 1e-10

# %%
x_train.columns
# Out:
# Index(['Store', 'Holiday_Flag', 'Temperature', 'Fuel_Price', 'CPI',
#        'Unemployment', 'Year', 'Month'],
#       dtype='object')

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import SGDRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error
import math
import joblib


def train_model(x_train, x_test, y_train, y_test, model_name):
    model_dict = {
        'linear_reg': LinearRegression,
        'SGD_reg': SGDRegressor,
        'RF_reg': RandomForestRegressor,
        'dtree_reg': DecisionTreeRegressor,
    }
    if model_name not in list(model_dict.keys()):
        raise ValueError(
            f"Only these options for model_name are allowed : {list(model_dict.keys())}")
    model = model_dict[model_name]()
    model.fit(x_train, y_train)
    pred = model.predict(x_test)
    # Evaluating the model
    print("r2_score: ",r2_score(y_test,pred))
    print("Mean absolute error: %.2f" % mean_absolute_error(y_test,pred))
    print("Root mean squared error: ", math.sqrt(mean_squared_error(y_test,pred)))
    #Plot the graph
    plt.figure(figsize=(10,10))
    plt.scatter(y_test,pred, c='crimson')
    p1 = max(max(pred), max(y_test))
    p2 = min(min(pred), min(y_test))
    plt.plot([p1, p2], [p1, p2], 'b-')
    plt.xlabel('True Values', fontsize=15)
    plt.ylabel('Predictions', fontsize=15)
    plt.axis('equal')
    plt.show()

    #return model for testing features later
    return model

# %%
train_model(x_train, x_test, y_train, y_test_open, 'linear_reg')
# Out:
# r2_score:  0.15364787763921628
# Mean absolute error: 427735.45
# Root mean squared error:  517929.4259311614
# LinearRegression()

# %%
train_model(x_train, x_test, y_train, y_test_open, 'SGD_reg')
# Out:
# r2_score:  -1.0603614412693419e+17
# Mean absolute error: 155925683790821.66
# Root mean squared error:  183325131651980.5
# SGDRegressor()

# %%
RF_reg_trainer = train_model(x_train, x_test, y_train, y_test_open, 'RF_reg')
#Adding to find the best features
# Out:
# r2_score:  0.9455322214442444
# Mean absolute error: 67883.11
# Root mean squared error:  131390.77482684393

# %%
train_model(x_train, x_test, y_train, y_test_open, 'dtree_reg')
# Out:
# r2_score:  0.8963663631236899
# Mean absolute error: 89703.67
# Root mean squared error:  181236.393696178
# DecisionTreeRegressor()

# %%
#RF regression has the lowest error
# getting weights of all the features used in the data
feature_importance = RF_reg_trainer.feature_importances_
feature_importance
# Out:
# array([0.64616978, 0.00587939, 0.01822836, 0.01626531, 0.17535275,
#        0.10513816, 0.00266778, 0.03029845])

# %%
# features used
columns = list(x_train.columns)
columns
# Out:
# ['Store',
#  'Holiday_Flag',
#  'Temperature',
#  'Fuel_Price',
#  'CPI',
#  'Unemployment',
#  'Year',
#  'Month']

# %%
feature_importance_value = []
for i in range(len(feature_importance)):
    feature_importance_value.append(round(feature_importance[i],5))
feature_importance_value
# Out:
# [0.64617, 0.00588, 0.01823, 0.01627, 0.17535, 0.10514, 0.00267, 0.0303]

# %%
# making a dataframe
feature_importance_df = pd.DataFrame({"Features":columns,
                                     "Values":feature_importance_value })
feature_importance_df
# Out:
#        Features   Values
# 0         Store  0.64617
# 1  Holiday_Flag  0.00588
# 2   Temperature  0.01823
# 3    Fuel_Price  0.01627
# 4           CPI  0.17535
# 5  Unemployment  0.10514
# 6          Year  0.00267
# 7         Month  0.03030

# %%
# @title Features

from matplotlib import pyplot as plt
import seaborn as sns
feature_importance_df.groupby('Features').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
feature_importance_df.sort_values(by=["Values"], inplace=True, ascending=False)
feature_importance_df
# Out:
#        Features   Values
# 0         Store  0.64617
# 4           CPI  0.17535
# 5  Unemployment  0.10514
# 7         Month  0.03030
# 2   Temperature  0.01823
# 3    Fuel_Price  0.01627
# 1  Holiday_Flag  0.00588
# 6          Year  0.00267

# %%
# Feature Importance
plt.figure(figsize=(15,6))

sns.barplot(x=feature_importance_df['Features'], y=feature_importance_df['Values'],
            data = feature_importance_df ).set(title='Feature Importance')

plt.xticks(rotation=90)
plt.show()
